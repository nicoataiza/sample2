# %%
# Install Streamlit
conda install streamlit

# %%
# Install Streamlit folium reader
conda install streamlit_folium

# %%
# Check if Streamlit is installed correctly
import streamlit as st
import streamlit_folium

# %%
# !pip install geopandas
# !pip install folium
# Out:
# Collecting geopandas
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\nico\anaconda3\lib\site-packages (from geopandas) (1.2.4)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\nico\anaconda3\lib\site-packages (from geopandas) (3.2.1)
# Requirement already satisfied: shapely in c:\users\nico\anaconda3\lib\site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\nico\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\nico\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\nico\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2021.1)
# Requirement already satisfied: certifi in c:\users\nico\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2020.12.5)
# Requirement already satisfied: six>=1.5 in c:\users\nico\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->geopandas) (1.15.0)
# Requirement already satisfied: cligj>=0.4 in c:\users\nico\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\nico\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in c:\users\nico\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\users\nico\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (7.1.2)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_50128ca26ae448789f30b95101f3a959\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_50128ca26ae448789f30b95101f3a959\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-mo95w634'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_50128ca26ae448789f30b95101f3a959\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_85216e871b0d464aafb13329bbb13f25\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_85216e871b0d464aafb13329bbb13f25\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-ktoc12gb'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_85216e871b0d464aafb13329bbb13f25\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_a6846acad64d40e281fe196800da2f04\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_a6846acad64d40e281fe196800da2f04\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-eb00u46l'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_a6846acad64d40e281fe196800da2f04\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_d7f2bffa90a94062a7c01e5129acd86a\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_d7f2bffa90a94062a7c01e5129acd86a\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-mornan61'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_d7f2bffa90a94062a7c01e5129acd86a\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_5096c833f1cb4c2ea2c0b382683a7df5\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_5096c833f1cb4c2ea2c0b382683a7df5\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-czcoeft2'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_5096c833f1cb4c2ea2c0b382683a7df5\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_3656b7f7e87d4c128d4b924d53ee56ec\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_3656b7f7e87d4c128d4b924d53ee56ec\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-_8255j1p'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_3656b7f7e87d4c128d4b924d53ee56ec\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_46ec7b89de6344e5bda72744040d3cc3\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_46ec7b89de6344e5bda72744040d3cc3\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info-wcndmmun'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_46ec7b89de6344e5bda72744040d3cc3\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/fd/5ec54f2d9b3d5dd23dd443fad5630d6b872e2664814c68b856c47e0d65af/Fiona-1.8.14.tar.gz#sha256=6eac038206c89d2cf5f99ea38b81cc228dc21eac5f47870a9a32d453b0007f4d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_5a2d0316f14a4b8786a44891f6aaae75\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_5a2d0316f14a4b8786a44891f6aaae75\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Nico\AppData\Local\Temp\pip-pip-egg-info
\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.8\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Nico\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_d795145b0fce4d33a03e5ceeb88e79bc\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_d795145b0fce4d33a03e5ceeb88e79bc\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Nico\AppData\Local\Temp\pip-record-0ercttbf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Nico\anaconda3\Include\fiona'
#          cwd: C:\Users\Nico\AppData\Local\Temp\pip-install-17byx8_l\fiona_d795145b0fce4d33a03e5ceeb88e79bc\
#     Complete output (12 lines):
#     C:\Users\Nico\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     C:\Users\Nico\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     C:\Users\Nico\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Nico\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_d795145b0fce4d33a03e5ceeb88e79bc\\setup.py'"'"'; __file__='"'"'C:\\Users\\Nico\\AppData\\Local\\Temp\\pip-install-17byx8_l\\fiona_d795145b0fce4d33a03e5ceeb88e79bc\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Nico\AppData\Local\Temp\pip-record-0ercttbf\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Nico\anaconda3\Include\fiona' Check the logs for full command output.
# Requirement already satisfied: folium in c:\users\nico\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: requests in c:\users\nico\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\nico\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\nico\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\nico\anaconda3\lib\site-packages (from folium) (1.20.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nico\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nico\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nico\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\nico\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nico\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)

# %%
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fc7d1d298f0c> in <module>
# ----> 1 import geopandas
#
# ModuleNotFoundError: No module named 'geopandas'

# %% [markdown]
# ## How to use this guide
# To run streamlit:
# 1. Open a text file then copy the code from one cell and save it as *filename.py*. ***OR***
#    Copy one cell to new Jupyter notebook then download as .py
#
#
# 2. In your anaconda prompt or terminal, go to the folder you saved the .py file in.
# 3. Type "streamlit run *filename.py*"
# 4. A new window should open displaying the results of the code. If not, click on the local URL.
# 5. Paste the content of a new cell in the same .py file then save. Refresh the streamlit window to view the updated output.

# %%
# 1: Seeing your data in Streamlit with st.write
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("data/2016-2019-voter-data.csv")

# st.write tells streamlit to write the content in the web app.
_____________________

# %%
#With magic commands, putting any variable in a new line will be read by streamlit
first10 = df.head(10)
first10

# %%
# 3: Adding text in page

# Add title to the page
st.title("Data")
# Add section header
st.header("data/2016-2019 Philippine Voter Dataset")

# Add any text
data_load_state = st.text('Loading data...')
df = pd.read_csv("data/2016-2019-voter-data.csv")
st.write(df.head(20))

# Customize texts using markdown
data_load_state.markdown('Loading data...**done!**')

# %%
# 4: Adding plots to Streamlit

region_voter = df.groupby("Region")["2019-Registered_Voters"].sum()

#Copy paste your code from Jupyter but assign plt.figure to variable

_____________________ = plt.figure(figsize=(8,6)) 

# the main code to create the graph
plt.bar(region_voter.index, region_voter.values) 

# additional elements that can be customzed
plt.title("Number of Registered Voters by Region", fontsize=16)
plt.ylabel("Number of Registered Voters", fontsize=12)
plt.xlabel("Region", fontsize=12)
plt.xticks(rotation=45)

# display graph
plt.show()

# display graph by plotting figure variable
st.write(plt)

# %%
# 5: Adding interactive options: checkbox

if st.checkbox('Show data', value=True):
    st.subheader('Data')
    data_load_state = st.text('Loading data...')
    st.write(df.head(20))
    data_load_state.markdown('Loading data...**done!**')

# %%
# 6: Adding interactive options: selectbox

#Create selectbox
option = st.selectbox("What region do you want to see?", value = df.Region.unique())

st.write()'You selected: ', option)

# Filter the entry in the plot
province_level = df[df["Region"]==option].groupby("Province")["2019-Registered_Voters"].sum()

# store figure in fig variable
fig = plt.figure(figsize=(8,6)) 

plt.bar(province_level.index, province_level.values) 

plt.title("Registered Voters by Province", fontsize=16)
plt.ylabel("Number of Registered Voters", fontsize=12)
plt.xlabel("Province", fontsize=12)
plt.xticks(rotation=45)

# display graph
st.pyplot(fig)

# %%
# 7: Adding options to sidebar

# st.sidebar moves the selectbox to the side
option = st.sidebar.selectbox("What region do you want to see?", value = df.Region.unique())

'You selected: ', option

# Filter the entry in the plot
province_level = df[df["Region"]==option].groupby("Province")["2019-Registered_Voters"].sum()

st.header(f"Barchart of {option}")

# store figure in fig variable
fig = plt.figure(figsize=(8,6)) 

plt.bar(province_level.index, province_level.values) 

plt.title("Registered Voters by Province", fontsize=16)
plt.ylabel("Number of Registered Voters", fontsize=12)
plt.xlabel("Province", fontsize=12)
plt.xticks(rotation=45)

# display graph
st.pyplot(fig)

# %%
# 8: Creating pages

df = pd.read_csv("data/2016-2019-voter-data.csv")
my_page = st.sidebar.radio('Page Navigation', ["page 1", "page 2"])

if my_page == "page 1":
    st.title("Data")
    st.header("2016-2019 Philippine Voter Dataset")
    if st.checkbox('Show data', value = True):
        st.subheader('Data')
        data_load_state = st.text('Loading data...')
        st.write(df.head(20))
        data_load_state.markdown('Loading data...**done!**')
    
elif my_page == "page 2":
    option = st.sidebar.selectbox('Which region do you want to see?', df['Region'].unique())

    'You selected: ', option

    # Filter the entry in the plot
    province_level = df[df['Region'] == option].groupby("Province")["2019-Registered_Voters"].sum()

    st.header(f"Barchart of {option}")

    # store figure in fig variable
    fig = plt.figure(figsize=(8,6)) 

    plt.bar(province_level.index, province_level.values) 

    plt.title("Registered Voters by Province", fontsize=16)
    plt.ylabel("Number of Registered Voters", fontsize=12)
    plt.xlabel("Province", fontsize=12)
    plt.xticks(rotation=45)

    # display graph
    st.pyplot(fig)

# %%
# 9: Reading folium in Streamlit (page 3)

import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from streamlit_folium import folium_static
import geopandas as gpd
import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv("data/2016-2019-voter-data.csv")
my_page = st.sidebar.radio('Page Navigation', ['page 1', 'page 2', 'page 3'])

if my_page == 'page 1':
    st.title("Data")
    st.header("2016-2019 Philippine Voter Dataset")
    if st.checkbox('Show data', value = True):
        st.subheader('Data')
        data_load_state = st.text('Loading data...')
        st.write(df.head(20))
        data_load_state.markdown('Loading data...**done!**')
    
elif my_page == 'page 2':
    option = st.sidebar.selectbox('Which region do you want to see?', df['Region'].unique())

    'You selected: ', option

    # Filter the entry in the plot
    province_level = df[df['Region'] == option].groupby("Province")["2019-Registered_Voters"].sum()

    st.header(f"Barchart of {option}")

    # store figure in fig variable
    fig = plt.figure(figsize=(8,6)) 

    plt.bar(province_level.index, province_level.values) 

    plt.title("Registered Voters by Province", fontsize=16)
    plt.ylabel("Number of Registered Voters", fontsize=12)
    plt.xlabel("Province", fontsize=12)
    plt.xticks(rotation=45)

    # display graph
    st.pyplot(fig)
    
elif my_page == 'page 3':
    st.title("Geospatial Analysis: Folium")
    shapefile = gpd.read_file('data/Provinces/Provinces.shp')
    shapefile["x"] = shapefile.geometry.centroid.x
    shapefile["y"] = shapefile.geometry.centroid.y
    map_center = [14.583197, 121.051538]

    # Styling the map
    mymap = folium.map(location=map_center, height=700, width=1000, tiles="OpenStreetMap", zoom_start=14)
    option_reg = st.sidebar.selectbox(
        'Which region',
        shapefile["REGION"].unique())
    
    'You selected: ', option_reg
    
    reg = option_reg
    df_reg = shapefile[shapefile["REGION"]==reg]

    for i in np.arange(len(df_reg)):
        lat = df_reg["y"].values[i]
        lon = df_reg["x"].values[i]
        name = df_reg["PROVINCE"].values[i]
        folium.Marker([lat, lon], popup=name).add_to(mymap)
    folium_static(mymap)

# %%
# 10: Plotting maps using st.map (page 4)import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from streamlit_folium import folium_static
import geopandas as gpd
import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv("data/2016-2019-voter-data.csv")
my_page = st.sidebar.radio('Page Navigation', ['page 1', 'page 2', 'page 3', 'page 4'])

if my_page == 'page 1':
    st.title("Data")
    st.header("2016-2019 Philippine Voter Dataset")
    if st.checkbox('Show data', value = True):
        st.subheader('Data')
        data_load_state = st.text('Loading data...')
        st.write(df.head(20))
        data_load_state.markdown('Loading data...**done!**')
    
elif my_page == 'page 2':
    option = st.sidebar.selectbox('Which region do you want to see?', df['Region'].unique())

    'You selected: ', option

    # Filter the entry in the plot
    province_level = df[df['Region'] == option].groupby("Province")["2019-Registered_Voters"].sum()

    st.header(f"Barchart of {option}")

    # store figure in fig variable
    fig = plt.figure(figsize=(8,6)) 

    plt.bar(province_level.index, province_level.values) 

    plt.title("Registered Voters by Province", fontsize=16)
    plt.ylabel("Number of Registered Voters", fontsize=12)
    plt.xlabel("Province", fontsize=12)
    plt.xticks(rotation=45)

    # display graph
    st.pyplot(fig)
    
elif my_page == 'page 3':
    st.title("Geospatial Analysis: Folium")
    shapefile = gpd.read_file('data/Provinces/Provinces.shp')
    shapefile["x"] = shapefile.geometry.centroid.x
    shapefile["y"] = shapefile.geometry.centroid.y
    map_center = [14.583197, 121.051538]

    # Styling the map
    mymap = folium.Map(location=map_center, height=700, width=1000, tiles="OpenStreetMap", zoom_start=14)
    option_reg = st.sidebar.selectbox(
        'Which region',
        shapefile["REGION"].unique())
    
    'You selected: ', option_reg
    
    reg = option_reg
    df_reg = shapefile[shapefile["REGION"]==reg]

    for i in np.arange(len(df_reg)):
        lat = df_reg["y"].values[i]
        lon = df_reg["x"].values[i]
        name = df_reg["PROVINCE"].values[i]
        folium.Marker([lat, lon], popup=name).add_to(mymap)
    folium_static(mymap)
    
elif my_page == 'page 4':
    st.title("Geospatial Analysis: st.map()")
    shapefile = gpd.read_file('data/Provinces/Provinces.shp')
    shapefile["lat"] = shapefile.geometry.centroid.x
    shapefile["lon"] = shapefile.geometry.centroid.y
    st.map(shapefile[["lat","lon"]])

elif my_page == 'page 5':
    st.title("Geospatial Analysis: Geopandas")
    merged_data = gpd.read_file('data/map_data_clean/map_data_clean.shp')
     # Copied from Mapping exercise
    variable = "voter_prec"
    vmin, vmax = merged_data["voter_prec"].min(), merged_data["voter_prec"].max()
    fig, ax = plt.subplots(1, figsize=(15, 10))
    merged_data.plot(column=variable, cmap='Oranges', linewidth=0.8, ax=ax, edgecolor='0.8', vmin=vmin, vmax=vmax)
    sm = plt.cm.ScalarMappable(cmap='Oranges', norm=plt.Normalize(vmin=vmin, vmax=vmax))
    cbar = fig.colorbar(sm)
    st.pyplot(fig)
